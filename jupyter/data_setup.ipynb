# %% [markdown]
# # Data Setup
# This notebook reads `penguins_size.csv` and loads it into the `data_db` PostgreSQL database.

# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# Database connection parameters
db_user = os.environ.get('POSTGRES_USER', 'data_user')
db_password = os.environ.get('POSTGRES_PASSWORD', 'data_password')
db_host = os.environ.get('POSTGRES_HOST', 'data_db')
db_name = os.environ.get('POSTGRES_DB', 'data_db')
db_port = '5432'

# Read data
try:
    df = pd.read_csv('/home/jovyan/work/penguins_size.csv')
    print(f"Loaded {len(df)} rows from CSV.")
    
    # Create database engine
    engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}')
    
    # Save to database
    df.to_sql('raw_penguins', engine, if_exists='replace', index=False)
    print("Successfully saved to database table 'raw_penguins'.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Loaded 344 rows from CSV.
# Successfully saved to database table 'raw_penguins'.
